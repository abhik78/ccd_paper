# %%
import rdkit.Chem as Chem
from rdkit.Chem import Draw
from rdkit.Chem import PandasTools
from rdkit.Chem.Draw import IPythonConsole # Enables RDKit IPython integration]
import pandas as pd

# %% [markdown]
# # preparing scaffold data for drug subset

# %%
drug_like = pd.read_csv('mcule_drugbank_drugcentarl_chembl.csv')

# %%
drug_like.head()
# Out:
#   CHEM_COMP_ID
# 0          SU0
# 1          TRI
# 2          X0T
# 3          CBL
# 4          MPT

# %%
df_scaffold = pd.read_csv('all_scaffolds.csv')

# %%
df_scaffold.head()
# Out:
#   CHEM_COMP_ID                                             SMILES
# 0          244                           c1ccc(-c2cc3ccccc3o2)cc1
# 1          SM1         O=C(CNC(=O)CNS(=O)(=O)Cc1ccccc1)NCc1ccccc1
# 2          NVV  O=C(c1ccccc1)[C@@H]1CNC[C@@H]1c1ccc2c(=O)[nH]c...
# 3          9UO                                c1ccc(-c2ncncn2)nc1
# 4          80R                   O=c1[nH]c2ccc(Nc3ccccc3)cc2[nH]1

# %%
drug_like_scaffold = pd.merge(drug_like, df_scaffold, on=['CHEM_COMP_ID'])

# %%
drug_like_scaffold
# Out:
#       CHEM_COMP_ID                                             SMILES
# 0              SU0                  O=C(Cc1cc(=O)oc2ccccc12)Nc1ccccc1
# 1              SU0                  O=C(Cc1cc(=O)oc2ccccc12)Nc1ccccc1
# 2              TRI                                         c1nnc[nH]1
# 3              X0T                       O=c1[nH]c(=O)c2[nH]cnc2[nH]1
# 4              CBL                                           c1ccccc1
# 5              8CL                                           c1ccccc1
# 6              617                           O=C(COc1ccccc1)Nc1ccccc1
# 7              245                            O=C(Nc1ccccc1)Nc1ccncc1
# 8              ETY                                           c1ccccc1
# 9              LPB                                            C1CSSC1
# 10             X8Z                                            C1CCNC1
# 11             3NF                                           c1ccccc1
# 12             B21                                 c1ccc(-c2ccco2)cc1
# 13             2BR                                           c1ccccc1
# 14             791                                           c1ccccc1
# 15             LOC                        O=c1cccc2c(c1)CCCc1ccccc1-2
# 16             IPB                                           c1ccccc1
# 17             MOA                                    O=C1OCc2ccccc21
# 18             TOR                    C1O[C@H]2COC3OCO[C@@H]3[C@H]2O1
# 19             OAM                     c1cn(CCCn2cnnc2-c2cn[nH]c2)cn1
# 20             AXC            c1ccc2[nH]c(CSc3nc4ccccc4c4ncnn34)nc2c1
# 21             IJZ                               O=c1cc[nH]c(=O)[nH]1
# 22             CCM                                            C1CCCC1
# 23             ZIT  O=C1C[C@@H](O[C@@H]2CCCCO2)C[C@H](O[C@H]2CCCCO...
# 24             DQN                                   O=C1C=CC(=O)C=C1
# 25             MRE                              c1ccc(N=Nc2ccccc2)cc1
# 26             MPX                            S=C(Nc1ccccc1)NN1CCNCC1
# 27             CT5             c1ccc(-c2[nH]ncc2-c2ccc3c(c2)OCCO3)cc1
# 28             GHP                                           c1ccccc1
# 29             TSS                                   c1ccc2[nH]ccc2c1
# ...            ...                                                ...
# 12270          VO2                       c1ccc(COc2cccnc2Nc2nccs2)cc1
# 12271          TFV                  c1ccc(NCCNc2ccnc(-c3ccccn3)n2)nc1
# 12272          1WL         O=C(NCCc1cnc[nH]1)c1ccc(C#CC#Cc2ccccc2)cc1
# 12273          F60                                   c1ccc2[nH]ccc2c1
# 12274          1Y0  O=C(N[C@@H]1CCOc2ccccc21)[C@H]1CN2[C@H](C[C@@H...
# 12275          Y0R                       c1ccc(-n2cc(-c3cccs3)nn2)cc1
# 12276          1QM              c1ccc(-c2n[nH]cc2-c2ccnc3c2OCCNC3)cc1
# 12277          28C                         c1ccc(CCNc2ccnn3cnnc23)cc1
# 12278          31Z  O=c1ccn([C@H]2CCCN(Cc3cccc(Oc4ccccc4)c3)C2)c(=...
# 12279          1MU                        O=S(=O)(NCCc1ccccc1)c1ccsc1
# 12280          31X  c1ccc(-c2nc(Cn3ccc4c(-c5cccc6ccccc56)nccc43)no...
# 12281          32C  O=c1ccn([C@H]2CCCN(Cc3cccc(Oc4ccccc4)c3)C2)c(=...
# 12282          QN7  C1=N[C@](c2ccncc2)(c2cccc(-c3ccccc3)c2)C2=NCCCN12
# 12283          1IS              c1ccc2sc(NC3CC(n4cnc5cccnc54)C3)nc2c1
# 12284          5G3                    c1ccc(N=C(c2ccccc2)c2ccccc2)cc1
# 12285          1YM                        c1cncc(-c2cnccc2-c2nccs2)c1
# 12286          2QA      O=C1CCCc2c1ccn2-c1cc2c(c(C3CCCC3)c1)C(=O)NCC2
# 12287          2W0                                   C=C1CCCc2ccccc21
# 12288          AZU                               O=c1cn[nH]c(=O)[nH]1
# 12289          2U5  O=C1C(Cc2ccccn2)C[C@H](c2ccccc2)[C@H](c2ccccc2...
# 12290          2U1  O=C1C(Cc2ccccn2)O[C@H](c2ccccc2)[C@@H](c2ccccc...
# 12291          2U7            O=C1CO[C@@H](c2ccccc2)[C@H](c2ccccc2)N1
# 12292          2D1                                 c1ccc(-c2cscn2)cc1
# 12293          YH1             O=C(CSc1nc2c(=O)[nH]cnc2[nH]1)c1ccccc1
# 12294          KVC          O=C1NCc2nc3ccccn3c2-c2cncc(n2)OCc2ccccc21
# 12295          2GK                                      c1ccc2sccc2c1
# 12296          1J9             O=C(COc1ncnc2c1cnn2-c1ccccc1)Nc1ccccn1
# 12297          KS2               c1ccc(-c2nnc([C@@H]3CCCCO3)[nH]2)cc1
# 12298          4BI                          c1ccc(-c2ccnc3ccccc23)cc1
# 12299          YA2                  C=C1CCC(=CC=C2CCCC3CCC[C@H]23)CC1
#
# [12300 rows x 2 columns]

# %%
drug_like_scaffold.to_csv('drug_like_scaffold.csv', index=False)

# %% [markdown]
# # preparing fragment data for drug subset

# %%
df_fragment = pd.read_csv('ccd_fragment.csv')

# %%
df_fragment.head()
# Out:
#   CHEM_COMP_ID    SMILES
# 0          SM1   CC(N)=O
# 1          SM1     NCC=O
# 2          244   c1ccoc1
# 3          244  c1ccccc1
# 4          SM1  c1ccccc1

# %%
drug_like_fragment = pd.merge(drug_like, df_fragment, on=['CHEM_COMP_ID'])

# %%
drug_like_fragment.to_csv('drug_like_fragment.csv')

# %% [markdown]
# # preparing cofactor data

# %%
df_cofactor = pd.read_csv('cofactor.csv')

# %%
cofactor_scaffold = pd.merge(df_cofactor, df_scaffold, on = ['CHEM_COMP_ID'])

# %%
cofactor_scaffold.head()
# Out:
#   CHEM_COMP_ID                                             SMILES
# 0          01A  O=C(CCCO[PH](=O)O[PH](=O)OC[C@H]1CC[C@@H](n2cn...
# 1          01K                        c1ncc2ncn([C@@H]3CCCO3)c2n1
# 2          0AF                                   c1ccc2[nH]ccc2c1
# 3          0ET                         c1ncc2ncn([C@H]3CCCO3)c2n1
# 4          0HG                                           c1ccccc1

# %%
cofactor_scaffold.to_csv('cofactor_scaffold.csv', index=False)

# %% [markdown]
# #  Preparing CDK2 kinase data

# %%
df_cdk2 = pd.read_csv('ligands_cdk2_P24941.csv')

# %%
cdk2_scaffold = pd.merge(df_cdk2, df_scaffold, on= ['CHEM_COMP_ID'])

# %%
cdk2_scaffold.head()
# Out:
#   CHEM_COMP_ID                        SMILES
# 0          LZC      c1cc2nc(NC3CCCCC3)ccn2n1
# 1          ZIP              c1ncc2nc[nH]c2n1
# 2          ES4              c1ncc2nc[nH]c2n1
# 3          HH5              c1ncc2[nH]cnc2n1
# 4          JYM  c1nc(OCC2CCCCC2)c2nc[nH]c2n1

# %%
cdk2_scaffold.to_csv('cdk2_scaffol.csv', index=False)

# %% [markdown]
# # preparing biopterin cofactor data

# %%
df_biopterin = pd.read_csv('biopterin_hetcodes.csv')

# %%
biopterin_scaffold = pd.merge(df_biopterin, df_scaffold, on = ['CHEM_COMP_ID'])

# %%
biopterin_scaffold.to_csv('biopterin_scaffold.csv', index=False)

# %% [markdown]
# # preparing phys chem property data for drug subset

# %%
df_ccd_prop = pd.read_csv('ccd_properties_clean.csv')

# %%
ccd_prop_drug = pd.merge(drug_like, df_ccd_prop, on=['CHEM_COMP_ID'])

# %%
ccd_prop_drug.head()
# Out:
#   CHEM_COMP_ID  Total Molweight   cLogP  H-Acceptors  H-Donors  Druglikeness  \
# 0          SU0         388.3990  1.1101          8.0       2.0       -3.3861
# 1          SU0         388.3990  1.1101          8.0       2.0       -3.3861
# 2          TRI              NaN     NaN          NaN       NaN           NaN
# 3          TRI          69.0668 -0.5705          3.0       1.0        1.5002
# 4          X0T         254.2450 -1.4165          8.0       2.0        4.4457
#
#    Rings
# 0    3.0
# 1    3.0
# 2    NaN
# 3    1.0
# 4    2.0

# %%
ccd_prop_drug.isnull().sum()
# Out:
# CHEM_COMP_ID          0
# Total Molweight    1296
# cLogP              1296
# H-Acceptors        1296
# H-Donors           1296
# Druglikeness       1296
# Rings              1296
# dtype: int64

# %%
ccd_prop_drug = ccd_prop_drug.dropna()

# %%
ccd_prop_drug.isnull().sum()
# Out:
# CHEM_COMP_ID       0
# Total Molweight    0
# cLogP              0
# H-Acceptors        0
# H-Donors           0
# Druglikeness       0
# Rings              0
# dtype: int64

# %%
ccd_prop_drug.to_csv('ccd_drug_prop.csv', index=False)
